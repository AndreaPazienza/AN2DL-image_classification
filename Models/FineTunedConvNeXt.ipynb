# %% [markdown]
# ## **Google Drive Connection**

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
import os
import zipfile
import shutil

#Create the paths to deirectories
main_directory_path = "/content/drive/MyDrive/CHALLENGE 2"
models_dir = main_directory_path + "/models/"
logs_dir = main_directory_path + "/logs/"
submission_dir = main_directory_path + "/submissions/"
data_dir = main_directory_path + "/new_data/"
#backup_dir = main_directory_path + "/backup compressed/"

# Create directories if they don't exist
os.makedirs(models_dir, exist_ok=True)
os.makedirs(logs_dir, exist_ok=True)
os.makedirs(submission_dir, exist_ok=True)
os.makedirs(data_dir, exist_ok=True)

# Create the paths to the compresssed files
train_compressed_path_FINALE = os.path.join(data_dir, "new_train_data_compressed.npz")
test_compressed_path_FINALE = os.path.join(data_dir, "new_test_data_compressed.npz")


train_tiles_compressed_path = os.path.join(data_dir, "new_train_tiles_compressed.npz")
test_tiles_compressed_path = os.path.join(data_dir, "new_test_tiles_compressed.npz")

# Create the paths to the train labels
train_labels_path = os.path.join(data_dir, "new_train_labels.csv")
train_labels_path_FINALE = os.path.join(data_dir, "new_labels.csv")

local_train_zip = "/content/new_train_data.zip"
local_test_zip  = "/content/new_test_data.zip"

# Cartelle di estrazione locali (SSD Colab)
local_train_dir = "/content/data/new_train_data"
local_test_dir  = "/content/data/new_test_data"

os.makedirs(local_train_dir, exist_ok=True)
os.makedirs(local_test_dir, exist_ok=True)

# %% [markdown]
# # **Libraries Import**

# %%
SEED = 42

# Set environment variables before importing modules
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(SEED)
random.seed(SEED)

# Import PyTorch
import torch
torch.manual_seed(SEED)
from torch import nn
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision.transforms import v2 as transforms
from torch.utils.data import TensorDataset, DataLoader

# Configurazione di TensorBoard e directory
# !pkill -f tensorboard
# %load_ext tensorboard
# !mkdir -p models

if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True
else:
    device = torch.device("cpu")

print(f"PyTorch version: {torch.__version__}")
print(f"Device: {device}")

# Import other libraries
import cv2
import copy
import shutil
from itertools import product
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split
from PIL import Image
import matplotlib.gridspec as gridspec
import requests
from io import BytesIO

from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import ExponentialLR
from torch.optim.lr_scheduler import StepLR

import hashlib
import re


# !pip install timm -q
import timm

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline

# Data saving
from datetime import datetime
data_ora_correnti = datetime.now()

data_formattata = data_ora_correnti.strftime("%Y%m%d_%H%M%S")
# Out:
# PyTorch version: 2.9.0+cu126
# Device: cuda

# %%
# Define the input shape based on the training data
input_shape = (3, 224, 224)

# Define the number of classes based on the categorical labels
num_classes = 4

# Define the batch size
BATCH_SIZE = 16

# %% [markdown]
# # **Data Loading**

# %%
# Load training and validation data as numPy vector from a compressed file (already preprocessed)
train_val = np.load(train_tiles_compressed_path)

# Separate the images from the masks in the training and validation set
train_images = train_val["images"]
train_names = train_val["names"]
train_labels = train_val["labels"]

# %%
print("Train tiles:", train_images.shape)
print("Train labels:", train_labels.shape)
# Out:
# Train tiles: (3371, 224, 224, 3)
# Train labels: (3371,)

# %%
# Inspect the target
print('Counting occurrences of target classes:')
print(pd.DataFrame(train_labels, columns=['digit'])['digit'].value_counts())
# Out:
# Counting occurrences of target classes:
# digit
# 1    1208
# 2     895
# 0     881
# 3     387
# Name: count, dtype: int64

# %% [markdown]
# #  **Data Preprocessing**

# %%
import numpy as np

def extract_image_ids(names):
    ids = []
    for n in names:
        base = n.split("_t")[0]
        num  = int(base.replace("img_", ""))
        ids.append(num)
    return np.array(ids)

image_ids = extract_image_ids(train_names)

# %%
# Augmentation and preprocessing for training set
train_augmentation = transforms.Compose([
    transforms.ToTensor(),
])

# Preprocessing for validation set
val_preprocessing = transforms.Compose([
    transforms.ToTensor(),
])

# %%
# @title Image-level train and validation split

# 1) LOAD NPZ WITH TILES

import numpy as np
from sklearn.model_selection import train_test_split
from scipy.stats import mode


# 2) EXTRACT IMAGE IDS FROM TILE NAMES

def extract_image_ids(names):
    ids = []
    for n in names:
        base = n.split("_t")[0]
        num  = int(base.replace("img_", ""))
        ids.append(num)
    return np.array(ids)

image_ids = extract_image_ids(train_names)
print("Unique images:", len(np.unique(image_ids)))



# 3) RECONSTRUCT ORIGINAL LABEL FOR EACH IMAGE (MAJORITY VOTE)

unique_ids = np.unique(image_ids)
image_level_labels = {}

for img_id in unique_ids:
    mask = (image_ids == img_id)
    modal_class = int(mode(train_labels[mask], keepdims=True)[0][0])
    image_level_labels[img_id] = modal_class

# Convert to aligned arrays for stratification
img_ids_array = np.array(list(image_level_labels.keys()))
img_cls_array = np.array(list(image_level_labels.values()))

print("Image-level classes distribution:", np.bincount(img_cls_array))


# 4) TRAIN/VAL SPLIT — STRATIFIED ON IMAGE LEVEL

train_ids, val_ids = train_test_split(
    img_ids_array,
    test_size=0.1,
    random_state=42,
    stratify=img_cls_array
)

print("Train images:", len(train_ids))
print("Val images:", len(val_ids))



# 5) BUILD TILE MASKS FOR FINAL SPLIT — NO LEAKAGE

train_preind = np.isin(image_ids, train_ids)
val_preind   = np.isin(image_ids, val_ids)

train_indices = np.where(train_preind)[0]
val_indices   = np.where(val_preind)[0]
# Out:
# Unique images: 581
# Image-level classes distribution: [158 204 150  69]
# Train images: 522
# Val images: 59

# %% [markdown]
# To prevent tiles from the same image from appearing in both the training and validation sets—which would result in **data leakage**—the train–validation split must be performed at the image level. Accordingly, we store the indices of the tiles associated with each image assigned to the training and validationation sets.

# %%
# @title Dataset and transformations performing

class IndexedDataset(torch.utils.data.Dataset):

    def __init__(self, tiles, labels, indices, transform=None):
        self.tiles = tiles
        self.labels = labels
        self.indices = indices
        self.transform = transform

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, i):
        idx = self.indices[i]

        image = self.tiles[idx]
        label = self.labels[idx]

        image_tensor = torch.from_numpy(image).permute(2,0,1).float()

        if self.transform:
            image_tensor = self.transform(image_tensor)

        return image_tensor, torch.tensor(label, dtype=torch.long)

# %% [markdown]
# Function to perform image transformations at the batch level, preventing RAM saturation.

# %%
def make_loader(ds, batch_size, shuffle, drop_last):
    # Determine optimal number of worker processes for data loading
    cpu_cores = os.cpu_count() or 2
    num_workers = max(2, min(4, cpu_cores))

    # Create DataLoader with performance optimizations
    return DataLoader(
        ds,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers,
        pin_memory=True,  # Faster GPU transfer
        pin_memory_device="cuda" if torch.cuda.is_available() else "",
        prefetch_factor=4,  # Load 4 batches ahead
    )

# %% [markdown]
# ## **Check loader creation**

# %%
train_ds = IndexedDataset(
    train_images, train_labels,
    indices=train_indices,
    transform=train_augmentation
)

val_ds = IndexedDataset(
    train_images, train_labels,
    indices=val_indices,
    transform=val_preprocessing
)

# %%
train_loader = make_loader(train_ds, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader   = make_loader(val_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, yb in train_loader:
    print("Features batch shape:", xb.shape)
    print("Labels batch shape:", yb.shape)
    break
# Out:
# Features batch shape: torch.Size([16, 3, 224, 224])
# Labels batch shape: torch.Size([16])

# %%
for x, y in train_loader:
    print(x.shape)
    break
# Out:
# torch.Size([16, 3, 224, 224])

# %% [markdown]
# # **Model Training**

# %%
def train_one_epoch(model, train_loader, criterion, optimizer, scaler, device, l1_lambda=0, l2_lambda=0):

    # Set model to training mode
    model.train()

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Iterate through training batches
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        # Move data to device (GPU/CPU)
        inputs, targets = inputs.to(device), targets.to(device)

        # Clear gradients from previous step
        optimizer.zero_grad(set_to_none=True)

        # Forward pass with mixed precision (if CUDA available)
        with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
            logits = model(inputs)
            loss = criterion(logits, targets)

            # Add L1 and L2 regularization
            l1_norm = sum(p.abs().sum() for p in model.parameters())
            l2_norm = sum(p.pow(2).sum() for p in model.parameters())
            loss = loss + l1_lambda * l1_norm + l2_lambda * l2_norm


        # Backward pass with gradient scaling
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()

        # Accumulate metrics
        running_loss += loss.item() * inputs.size(0)
        predictions = logits.argmax(dim=1)
        all_predictions.append(predictions.cpu().numpy())
        all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_f1 = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_f1

# %%
def validate_one_epoch(model, val_loader, criterion, device):

    # Set model to evaluation mode
    model.eval()

    running_loss = 0.0
    all_predictions = []
    all_targets = []

    # Disable gradient computation for validation
    with torch.no_grad():
        for inputs, targets in val_loader:
            # Move data to device
            inputs, targets = inputs.to(device), targets.to(device)

            # Forward pass with mixed precision (if CUDA available)
            with torch.amp.autocast(device_type=device.type, enabled=(device.type == 'cuda')):
                logits = model(inputs)
                loss = criterion(logits, targets)

            # Accumulate metrics
            running_loss += loss.item() * inputs.size(0)
            predictions = logits.argmax(dim=1)
            all_predictions.append(predictions.cpu().numpy())
            all_targets.append(targets.cpu().numpy())

    # Calculate epoch metrics
    epoch_loss = running_loss / len(val_loader.dataset)
    epoch_accuracy = f1_score(
        np.concatenate(all_targets),
        np.concatenate(all_predictions),
        average='weighted'
    )

    return epoch_loss, epoch_accuracy

# %%
def log_metrics_to_tensorboard(writer, epoch, train_loss, train_f1, val_loss, val_f1, model):

    # Log scalar metrics
    writer.add_scalar('Loss/Training', train_loss, epoch)
    writer.add_scalar('Loss/Validation', val_loss, epoch)
    writer.add_scalar('F1/Training', train_f1, epoch)
    writer.add_scalar('F1/Validation', val_f1, epoch)

    # Log model parameters and gradients
    for name, param in model.named_parameters():
        if param.requires_grad:
            # Check if the tensor is not empty before adding a histogram
            if param.numel() > 0:
                writer.add_histogram(f'{name}/weights', param.data, epoch)
            if param.grad is not None:
                # Check if the gradient tensor is not empty before adding a histogram
                if param.grad.numel() > 0:
                    if param.grad is not None and torch.isfinite(param.grad).all():
                        writer.add_histogram(f'{name}/gradients', param.grad.data, epoch)

# %%
def fit(model, train_loader, val_loader, epochs, criterion, optimizer, scaler, device,scheduler=None,
        l1_lambda=0, l2_lambda=0, patience=0, evaluation_metric="val_f1", mode='max',
        restore_best_weights=True, writer=None, verbose=10, experiment_name=""):

    # Initialize metrics tracking
    training_history = {
        'train_loss': [], 'val_loss': [],
        'train_f1': [], 'val_f1': []
    }

    # Configure early stopping if patience is set
    if patience > 0:
        patience_counter = 0
        best_metric = float('-inf') if mode == 'max' else float('inf')
        best_epoch = 0
        # Define model_save_path here so it's available for restoring weights
        model_save_path = f"{models_dir}{experiment_name}_model.pt"

    print(f"Training {epochs} epochs...")

    # Main training loop: iterate through epochs
    for epoch in range(1, epochs + 1):

        # Forward pass through training data, compute gradients, update weights
        train_loss, train_f1 = train_one_epoch(
            model, train_loader, criterion, optimizer, scaler, device, l1_lambda, l2_lambda
        )

        # Evaluate model on validation data without updating weights
        val_loss, val_f1 = validate_one_epoch(
            model, val_loader, criterion, device
        )

        # Store metrics for plotting and analysis
        training_history['train_loss'].append(train_loss)
        training_history['val_loss'].append(val_loss)
        training_history['train_f1'].append(train_f1)
        training_history['val_f1'].append(val_f1)

        # Write metrics to TensorBoard for visualization
        if writer is not None:
            log_metrics_to_tensorboard(
                writer, epoch, train_loss, train_f1, val_loss, val_f1, model
            )


        # Step scheduler after validation metrics are available
        if scheduler is not None:
            if isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau) and evaluation_metric == "val_f1":
                scheduler.step(val_f1)
            elif isinstance(scheduler, torch.optim.lr_scheduler.ReduceLROnPlateau) and evaluation_metric == "val_loss":
                scheduler.step(val_loss)
            else:
                scheduler.step()

        # Print progress every N epochs or on first epoch
        if verbose > 0:
            if epoch % verbose == 0 or epoch == 1:
                print(f"Epoch {epoch:3d}/{epochs} | "
                    f"Train: Loss={train_loss:.4f}, F1 Score={train_f1:.4f} | "
                    f"Val: Loss={val_loss:.4f}, F1 Score={val_f1:.4f}")

        # Early stopping logic: monitor metric and save best model
        if patience > 0:
            current_metric = training_history[evaluation_metric][-1]
            is_improvement = (current_metric > best_metric) if mode == 'max' else (current_metric < best_metric)

            if is_improvement:
                best_metric = current_metric
                best_epoch = epoch
                print(f"New best {evaluation_metric}: {best_metric:.4f} at epoch {best_epoch}")
                # torch.save(model.state_dict(), "models/"+experiment_name+'_model.pt')
                os.makedirs(os.path.dirname(model_save_path), exist_ok=True)
                torch.save(model.state_dict(), model_save_path)
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience:
                    print(f"Early stopping triggered after {epoch} epochs.")
                    break

    history_save_path = f"{models_dir}{experiment_name}_history.pt"
    os.makedirs(os.path.dirname(history_save_path), exist_ok=True)
    torch.save(training_history, history_save_path)

    # Restore best model weights if early stopping was used
    if restore_best_weights and patience > 0:
        model_load_path = f"{models_dir}{experiment_name}_model.pt" # Use models_dir for loading
        model.load_state_dict(torch.load(model_load_path))
        print(f"Best model restored from epoch {best_epoch} with {evaluation_metric} {best_metric:.4f}")

    # Save final model if no early stopping
    if patience == 0:
        torch.save(model.state_dict(), f"{models_dir}{experiment_name}_model.pt")

    # Close TensorBoard writer
    if writer is not None:
        writer.close()

    return model, training_history

# %% [markdown]
# #  **Transfer Learning**

# %% [markdown]
# Learning the last classifier layer of the Vision Transformer with learning rate equal to $1\times10^{-4}$

# %%
# @title Transfer learning augmentation cell

train_augmentation_TL = None
val_preprocessing_TL = None

# %%
train_ds_TL = IndexedDataset(
    train_images, train_labels,
    indices=train_indices,
    transform=train_augmentation_TL
)

val_ds_TL = IndexedDataset(
    train_images, train_labels,
    indices=val_indices,
    transform=val_preprocessing_TL
)

# %%
train_loader_TL = make_loader(train_ds_TL, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader_TL   = make_loader(val_ds_TL, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, yb in train_loader_TL:
    print("Features batch shape:", xb.shape)
    print("Labels batch shape:", yb.shape)
    break # Stop after getting one batch
# Out:
# Features batch shape: torch.Size([16, 3, 224, 224])
# Labels batch shape: torch.Size([16])

# %%
# @title Model class

class ConvexTransfer(nn.Module):

    def __init__(self, model_name="convnext_large.fb_in22k", num_classes=4, dropout_rate=0.5, freeze_backbone=True):
        super().__init__()

        # Load pretrained ViT from timm
        self.backbone = timm.create_model(
            model_name,
            pretrained=True,
            num_classes=0
        )

        embed_dim = self.backbone.num_features

        # Freeze backbone
        if freeze_backbone:
            for p in self.backbone.parameters():
                p.requires_grad = False

        # New classification head
        self.head = nn.Sequential(
            nn.Linear(embed_dim, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout_rate),
            nn.Linear(256, num_classes),
        )

    def forward(self, x):
        feats = self.backbone(x)
        return self.head(feats)

# %%
experiment_name= "FineTunedConvNeXt"+ '_' + data_formattata

# Number of training epochs
LEARNING_RATE = 3e-4
EPOCHS = 200
PATIENCE = 20

# Regularisation
DROPOUT_RATE = 0.2       # Dropout probability
L1_LAMBDA = 0            # L1 penalty
L2_LAMBDA = 0            # L2 penalty

# Scheduler
SCHED_NAME = 'warm'
SCHEDULER_SIZE = 0.9
SCHEDULER_WAIT = 2
COS_PERIOD = 5
ETA_MIN = 1e-6
AMPLITUDE = 0.5
MODE = 'max'             # 'max' se monitori F1, 'min' se monitori loss




# Create transfer learning model
TL_model = ConvexTransfer(num_classes=num_classes, dropout_rate=DROPOUT_RATE).to(device)

summary(TL_model, input_size=input_shape)


writer = SummaryWriter(log_dir=logs_dir)
x = torch.randn(1, input_shape[0], input_shape[1], input_shape[2]).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/919M [00:00<?, ?B/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 192, 56, 56]           9,408
#        LayerNorm2d-2          [-1, 192, 56, 56]             384
#           Identity-3          [-1, 192, 56, 56]               0
#             Conv2d-4          [-1, 192, 56, 56]           9,600
#          LayerNorm-5          [-1, 56, 56, 192]             384
#             Linear-6          [-1, 56, 56, 768]         148,224
#               GELU-7          [-1, 56, 56, 768]               0
#            Dropout-8          [-1, 56, 56, 768]               0
#           Identity-9          [-1, 56, 56, 768]               0
#            Linear-10          [-1, 56, 56, 192]         147,648
#           Dropout-11          [-1, 56, 56, 192]               0
#               Mlp-12          [-1, 56, 56, 192]               0
#          Identity-13          [-1, 192, 56, 56]               0
#          Identity-14          [-1, 192, 56, 56]               0
#     ConvNeXtBlock-15          [-1, 192, 56, 56]               0
#            Conv2d-16          [-1, 192, 56, 56]           9,600
#         LayerNorm-17          [-1, 56, 56, 192]             384
#            Linear-18          [-1, 56, 56, 768]         148,224
#              GELU-19          [-1, 56, 56, 768]               0
#           Dropout-20          [-1, 56, 56, 768]               0
#          Identity-21          [-1, 56, 56, 768]               0
#            Linear-22          [-1, 56, 56, 192]         147,648
#           Dropout-23          [-1, 56, 56, 192]               0
#               Mlp-24          [-1, 56, 56, 192]               0
#          Identity-25          [-1, 192, 56, 56]               0
#          Identity-26          [-1, 192, 56, 56]               0
#     ConvNeXtBlock-27          [-1, 192, 56, 56]               0
#            Conv2d-28          [-1, 192, 56, 56]           9,600
#         LayerNorm-29          [-1, 56, 56, 192]             384
#            Linear-30          [-1, 56, 56, 768]         148,224
#              GELU-31          [-1, 56, 56, 768]               0
#           Dropout-32          [-1, 56, 56, 768]               0
#          Identity-33          [-1, 56, 56, 768]               0
#          Dropout-437           [-1, 7, 7, 6144]               0
#         Identity-438           [-1, 7, 7, 6144]               0
#           Linear-439           [-1, 7, 7, 1536]       9,438,720
#          Dropout-440           [-1, 7, 7, 1536]               0
#              Mlp-441           [-1, 7, 7, 1536]               0
#         Identity-442           [-1, 1536, 7, 7]               0
#         Identity-443           [-1, 1536, 7, 7]               0
#    ConvNeXtBlock-444           [-1, 1536, 7, 7]               0
#    ConvNeXtStage-445           [-1, 1536, 7, 7]               0
#         Identity-446           [-1, 1536, 7, 7]               0
# AdaptiveAvgPool2d-447           [-1, 1536, 1, 1]               0
#         Identity-448           [-1, 1536, 1, 1]               0
# SelectAdaptivePool2d-449           [-1, 1536, 1, 1]               0
#      LayerNorm2d-450           [-1, 1536, 1, 1]           3,072
#          Flatten-451                 [-1, 1536]               0
#         Identity-452                 [-1, 1536]               0
#          Dropout-453                 [-1, 1536]               0
#         Identity-454                 [-1, 1536]               0
# NormMlpClassifierHead-455                 [-1, 1536]               0
#         ConvNeXt-456                 [-1, 1536]               0
#           Linear-457                  [-1, 256]         393,472
#             ReLU-458                  [-1, 256]               0
#          Dropout-459                  [-1, 256]               0
#           Linear-460                    [-1, 4]           1,028
# ================================================================
# Total params: 196,597,764
# Trainable params: 394,500
# Non-trainable params: 196,203,264
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 1316.81
# Params size (MB): 749.96
# Estimated Total Size (MB): 2067.34
# ----------------------------------------------------------------

# %%
# %%time

# Re-initialize optimizer and scheduler for the transfer learning model
optimizer = torch.optim.Adam(TL_model.parameters(), lr=LEARNING_RATE)

criterion = nn.CrossEntropyLoss()

scaler = torch.amp.GradScaler(enabled=(device.type == 'cuda'))

# Scheduler setting
if SCHED_NAME == 'plat':
  scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode='max',
        factor=SCHEDULER_SIZE,
        patience=SCHEDULER_WAIT,
        min_lr=1e-4
    )
elif SCHED_NAME == 'step':
  scheduler = StepLR(optimizer, step_size= SCHEDULER_WAIT, gamma=SCHEDULER_SIZE)
elif SCHED_NAME == 'cosine':
  scheduler = CosineAnnealingLR(optimizer, T_max= COS_PERIOD, eta_min=ETA_MIN)
elif SCHED_NAME == 'exp':
  scheduler = ExponentialLR(optimizer, gamma=SCHEDULER_SIZE)
elif SCHED_NAME == 'warm':
  scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,
    T_mult=2
)
else:
  scheduler = None


# Train with transfer learning
tl_model, tl_history = fit(
    model=TL_model,
    train_loader=train_loader_TL,
    val_loader=val_loader_TL,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scheduler = scheduler,
    scaler=scaler,
    device=device,
    writer=writer,
    verbose=1,
    experiment_name=experiment_name,
    patience=PATIENCE
)

final_val_acc = round(max(tl_history['val_f1']) * 100, 2) # Changed to val_f1, as accuracy was not tracked
print(f'Final validation F1 score: {final_val_acc}%')
# Out:
# Training 200 epochs...
# Epoch   1/200 | Train: Loss=1.2842, F1 Score=0.3196 | Val: Loss=1.3573, F1 Score=0.2193
# New best val_f1: 0.2193 at epoch 1
# Epoch   2/200 | Train: Loss=1.2378, F1 Score=0.3882 | Val: Loss=1.3623, F1 Score=0.2407
# New best val_f1: 0.2407 at epoch 2
# Epoch   3/200 | Train: Loss=1.2061, F1 Score=0.4189 | Val: Loss=1.3543, F1 Score=0.3325
# New best val_f1: 0.3325 at epoch 3
# Epoch   4/200 | Train: Loss=1.1730, F1 Score=0.4441 | Val: Loss=1.3735, F1 Score=0.3198
# Epoch   5/200 | Train: Loss=1.1516, F1 Score=0.4724 | Val: Loss=1.3901, F1 Score=0.3149
# Epoch   6/200 | Train: Loss=1.1326, F1 Score=0.4951 | Val: Loss=1.3850, F1 Score=0.3324
# Epoch   7/200 | Train: Loss=1.1134, F1 Score=0.5121 | Val: Loss=1.3773, F1 Score=0.3497
# New best val_f1: 0.3497 at epoch 7
# Epoch   8/200 | Train: Loss=1.0987, F1 Score=0.5188 | Val: Loss=1.3803, F1 Score=0.3283
# Epoch   9/200 | Train: Loss=1.0919, F1 Score=0.5289 | Val: Loss=1.3838, F1 Score=0.3229
# Epoch  10/200 | Train: Loss=1.0838, F1 Score=0.5355 | Val: Loss=1.3806, F1 Score=0.3305
# Epoch  11/200 | Train: Loss=1.1071, F1 Score=0.5056 | Val: Loss=1.3793, F1 Score=0.3248
# Epoch  12/200 | Train: Loss=1.0947, F1 Score=0.5200 | Val: Loss=1.4167, F1 Score=0.3137
# Epoch  13/200 | Train: Loss=1.0737, F1 Score=0.5394 | Val: Loss=1.4508, F1 Score=0.3064
# Epoch  14/200 | Train: Loss=1.0418, F1 Score=0.5485 | Val: Loss=1.4264, F1 Score=0.3042
# Epoch  15/200 | Train: Loss=1.0328, F1 Score=0.5653 | Val: Loss=1.5367, F1 Score=0.3012
# Epoch  16/200 | Train: Loss=1.0068, F1 Score=0.5751 | Val: Loss=1.4298, F1 Score=0.2888
# Epoch  17/200 | Train: Loss=0.9834, F1 Score=0.5869 | Val: Loss=1.4463, F1 Score=0.3236
# Epoch  18/200 | Train: Loss=0.9619, F1 Score=0.5998 | Val: Loss=1.5178, F1 Score=0.3052
# Epoch  19/200 | Train: Loss=0.9450, F1 Score=0.6028 | Val: Loss=1.4691, F1 Score=0.3026
# Epoch  20/200 | Train: Loss=0.9198, F1 Score=0.6234 | Val: Loss=1.5085, F1 Score=0.2970
# Epoch  21/200 | Train: Loss=0.9074, F1 Score=0.6213 | Val: Loss=1.5199, F1 Score=0.2949
# Epoch  22/200 | Train: Loss=0.8865, F1 Score=0.6500 | Val: Loss=1.5208, F1 Score=0.3070
# Epoch  23/200 | Train: Loss=0.8769, F1 Score=0.6425 | Val: Loss=1.5290, F1 Score=0.3023
# Epoch  24/200 | Train: Loss=0.8609, F1 Score=0.6591 | Val: Loss=1.5482, F1 Score=0.3008
# Epoch  25/200 | Train: Loss=0.8505, F1 Score=0.6620 | Val: Loss=1.5408, F1 Score=0.3059
# Epoch  26/200 | Train: Loss=0.8435, F1 Score=0.6694 | Val: Loss=1.5463, F1 Score=0.3088
# Epoch  27/200 | Train: Loss=0.8380, F1 Score=0.6689 | Val: Loss=1.5494, F1 Score=0.3091
# Early stopping triggered after 27 epochs.
# Best model restored from epoch 7 with val_f1 0.3497
# Final validation F1 score: 34.97%
# CPU times: user 9min 15s, sys: 2min 12s, total: 11min 27s
# Wall time: 12min 5s

# %% [markdown]
# # **Fine-Tuning**

# %% [markdown]
# Adjusting the weights of the backbone with learning rate equal to $1\times10^{-5}$ and the head with learning rate equal to $3\times10^{-5}$. Differential learning rate is useful to prevent overfitting.

# %%
# @title Fine-tuning augmentation cell

train_augmentation_ft = None
val_preprocessing_ft = None

# %%
train_ds_ft = IndexedDataset(
    train_images, train_labels,
    indices=train_indices,
    transform=train_augmentation_ft
)

val_ds_ft = IndexedDataset(
    train_images, train_labels,
    indices=val_indices,
    transform=val_preprocessing_ft
)

# %%
train_loader_ft = make_loader(train_ds_ft, batch_size=BATCH_SIZE, shuffle=True, drop_last=False)
val_loader_ft   = make_loader(val_ds_ft, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
# Get one batch from the training data loader
for xb, yb in train_loader_ft:
    print("Features batch shape:", xb.shape)
    print("Labels batch shape:", yb.shape)
    break # Stop after getting one batch
# Out:
# Features batch shape: torch.Size([16, 3, 224, 224])
# Labels batch shape: torch.Size([16])

# %%
UNFREEZE=1

# Load the model from the previous transfer learning phase
ft_model = ConvexTransfer(num_classes=num_classes, dropout_rate=DROPOUT_RATE).to(device)
ft_model.load_state_dict(torch.load(models_dir + experiment_name + "_model.pt", map_location=device))

# Freeze everything
for param in ft_model.backbone.parameters():
    param.requires_grad = False


# Unfreeze the last Transformer block (corrected for ConvNeXt's 'stages' structure)
# Assuming UNFREEZE refers to the number of *stages* to unfreeze from the end
for stage in ft_model.backbone.stages[-UNFREEZE:]:
    for param in stage.parameters():
        param.requires_grad = True


# Ensure the classifier head is always trainable
for param in ft_model.head.parameters():
    param.requires_grad = True


# Inspect how many parameters are trainable
total_params = sum(p.numel() for p in ft_model.parameters())
trainable_params = sum(p.numel() for p in ft_model.parameters() if p.requires_grad)


print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")
print(f"Frozen parameters: {total_params - trainable_params:,}")


print("\nTrainable layers:")
for name, param in ft_model.named_parameters():
    if param.requires_grad:
        print(f"  {name}: {param.numel():,} parameters")
# Out:
# Total parameters: 196,624,836
# Trainable parameters: 62,006,532
# Frozen parameters: 134,618,304
#
# Trainable layers:
#   backbone.stages.3.downsample.0.weight: 768 parameters
#   backbone.stages.3.downsample.0.bias: 768 parameters
#   backbone.stages.3.downsample.1.weight: 4,718,592 parameters
#   backbone.stages.3.downsample.1.bias: 1,536 parameters
#   backbone.stages.3.blocks.0.gamma: 1,536 parameters
#   backbone.stages.3.blocks.0.conv_dw.weight: 75,264 parameters
#   backbone.stages.3.blocks.0.conv_dw.bias: 1,536 parameters
#   backbone.stages.3.blocks.0.norm.weight: 1,536 parameters
#   backbone.stages.3.blocks.0.norm.bias: 1,536 parameters
#   backbone.stages.3.blocks.0.mlp.fc1.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.0.mlp.fc1.bias: 6,144 parameters
#   backbone.stages.3.blocks.0.mlp.fc2.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.0.mlp.fc2.bias: 1,536 parameters
#   backbone.stages.3.blocks.1.gamma: 1,536 parameters
#   backbone.stages.3.blocks.1.conv_dw.weight: 75,264 parameters
#   backbone.stages.3.blocks.1.conv_dw.bias: 1,536 parameters
#   backbone.stages.3.blocks.1.norm.weight: 1,536 parameters
#   backbone.stages.3.blocks.1.norm.bias: 1,536 parameters
#   backbone.stages.3.blocks.1.mlp.fc1.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.1.mlp.fc1.bias: 6,144 parameters
#   backbone.stages.3.blocks.1.mlp.fc2.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.1.mlp.fc2.bias: 1,536 parameters
#   backbone.stages.3.blocks.2.gamma: 1,536 parameters
#   backbone.stages.3.blocks.2.conv_dw.weight: 75,264 parameters
#   backbone.stages.3.blocks.2.conv_dw.bias: 1,536 parameters
#   backbone.stages.3.blocks.2.norm.weight: 1,536 parameters
#   backbone.stages.3.blocks.2.norm.bias: 1,536 parameters
#   backbone.stages.3.blocks.2.mlp.fc1.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.2.mlp.fc1.bias: 6,144 parameters
#   backbone.stages.3.blocks.2.mlp.fc2.weight: 9,437,184 parameters
#   backbone.stages.3.blocks.2.mlp.fc2.bias: 1,536 parameters
#   head.0.weight: 393,216 parameters
#   head.0.bias: 256 parameters
#   head.3.weight: 1,024 parameters
#   head.3.bias: 4 parameters

# %%
# %%time

# Setting differential learning rates
lr_backbone = 1e-5
lr_head     = 3e-5

optimizer = torch.optim.AdamW([
    {"params": ft_model.backbone.stages[-UNFREEZE:].parameters(), "lr": lr_backbone},
    {"params": ft_model.head.parameters(), "lr": lr_head},
], weight_decay=0)


# Fine-tune the model
ft_model, training_history = fit(
    model=ft_model,
    train_loader=train_loader_ft,
    val_loader=val_loader_ft,
    epochs=EPOCHS,
    criterion=criterion,
    optimizer=optimizer,
    scaler=scaler,
    scheduler = scheduler,
    device=device,
    writer=writer,
    verbose=1,
    experiment_name=experiment_name,
    patience=PATIENCE
)

final_val_acc = round(max(training_history['val_f1']) * 100, 2)
print(f'Final validation accuracy: {final_val_acc}%')
# Out:
# Training 200 epochs...
# Epoch   1/200 | Train: Loss=1.1011, F1 Score=0.5195 | Val: Loss=1.4008, F1 Score=0.3312
# New best val_f1: 0.3312 at epoch 1
# Epoch   2/200 | Train: Loss=1.0534, F1 Score=0.5442 | Val: Loss=1.4497, F1 Score=0.3096
# Epoch   3/200 | Train: Loss=0.9992, F1 Score=0.5749 | Val: Loss=1.4912, F1 Score=0.3237
# Epoch   4/200 | Train: Loss=0.9266, F1 Score=0.6219 | Val: Loss=1.5550, F1 Score=0.3188
# Epoch   5/200 | Train: Loss=0.8334, F1 Score=0.6653 | Val: Loss=1.5895, F1 Score=0.3113
# Epoch   6/200 | Train: Loss=0.7476, F1 Score=0.7140 | Val: Loss=1.7002, F1 Score=0.3065
# Epoch   7/200 | Train: Loss=0.6432, F1 Score=0.7709 | Val: Loss=1.7112, F1 Score=0.3003
# Epoch   8/200 | Train: Loss=0.5623, F1 Score=0.8127 | Val: Loss=1.8146, F1 Score=0.3140
# Epoch   9/200 | Train: Loss=0.4678, F1 Score=0.8584 | Val: Loss=1.8787, F1 Score=0.3280
# Epoch  10/200 | Train: Loss=0.3772, F1 Score=0.8998 | Val: Loss=1.9982, F1 Score=0.3244
# Epoch  11/200 | Train: Loss=0.2992, F1 Score=0.9337 | Val: Loss=2.0838, F1 Score=0.3121
# Epoch  12/200 | Train: Loss=0.2219, F1 Score=0.9652 | Val: Loss=2.1177, F1 Score=0.3251
# Epoch  13/200 | Train: Loss=0.1709, F1 Score=0.9777 | Val: Loss=2.2367, F1 Score=0.3167
# Epoch  14/200 | Train: Loss=0.1251, F1 Score=0.9878 | Val: Loss=2.3803, F1 Score=0.2843
# Epoch  15/200 | Train: Loss=0.0902, F1 Score=0.9961 | Val: Loss=2.4571, F1 Score=0.2963
# Epoch  16/200 | Train: Loss=0.0640, F1 Score=0.9987 | Val: Loss=2.6609, F1 Score=0.3034
# Epoch  17/200 | Train: Loss=0.0448, F1 Score=0.9997 | Val: Loss=2.6843, F1 Score=0.3257
# Epoch  18/200 | Train: Loss=0.0330, F1 Score=1.0000 | Val: Loss=2.7984, F1 Score=0.3057
# Epoch  19/200 | Train: Loss=0.0249, F1 Score=1.0000 | Val: Loss=2.9329, F1 Score=0.3023
# Epoch  20/200 | Train: Loss=0.0188, F1 Score=1.0000 | Val: Loss=3.0081, F1 Score=0.3222
# Epoch  21/200 | Train: Loss=0.0144, F1 Score=1.0000 | Val: Loss=3.1054, F1 Score=0.3244
# Early stopping triggered after 21 epochs.
# Best model restored from epoch 1 with val_f1 0.3312
# Final validation accuracy: 33.12%
# CPU times: user 11min 51s, sys: 1min 43s, total: 13min 35s
# Wall time: 13min 23s

# %% [markdown]
# ## **Plot History**

# %%
# Create a figure with two side-by-side subplots (two columns)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(18, 5))

# Plot of training and validation loss on the first axis
ax1.plot(training_history['train_loss'], label='Training loss', alpha=0.3, color='#ff7f0e', linestyle='--')
ax1.plot(training_history['val_loss'], label='Validation loss', alpha=0.9, color='#ff7f0e')
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=0.3)

# Plot of training and validation accuracy on the second axis
ax2.plot(training_history['train_f1'], label='Training f1', alpha=0.3, color='#ff7f0e', linestyle='--')
ax2.plot(training_history['val_f1'], label='Validation f1', alpha=0.9, color='#ff7f0e')
ax2.set_title('F1 Score')
ax2.legend()
ax2.grid(alpha=0.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# ## **Plot Confusion Matrix**

# %%
# Collect predictions and ground truth labels
val_preds, val_targets = [], []
with torch.no_grad():  # Disable gradient computation for inference
    for xb, yb in val_loader_ft:
        xb = xb.to(device)

        # Forward pass: get model predictions
        logits = ft_model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()

        # Store batch results
        val_preds.append(preds)
        val_targets.append(yb.numpy())

# Combine all batches into single arrays
val_preds = np.concatenate(val_preds)
val_targets = np.concatenate(val_targets)

# Calculate overall validation metrics
val_acc = accuracy_score(val_targets, val_preds)
val_prec = precision_score(val_targets, val_preds, average='weighted')
val_rec = recall_score(val_targets, val_preds, average='weighted')
val_f1 = f1_score(val_targets, val_preds, average='weighted')
print(f"Accuracy over the validation set: {val_acc:.4f}")
print(f"Precision over the validation set: {val_prec:.4f}")
print(f"Recall over the validation set: {val_rec:.4f}")
print(f"F1 score over the validation set: {val_f1:.4f}")

# Generate confusion matrix for detailed error analysis
cm = confusion_matrix(val_targets, val_preds)

# Create numeric labels for heatmap annotation
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Visualise confusion matrix
plt.figure(figsize=(8, 7))
sns.heatmap(cm, annot=labels, fmt='',
            cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix — Validation Set')
plt.tight_layout()
plt.show()
# Out:
# Accuracy over the validation set: 0.3405
# Precision over the validation set: 0.3661
# Recall over the validation set: 0.3405
# F1 score over the validation set: 0.3312

# %% [markdown]
# The confusion matrix shows that this pre-trained ConvexNet predicts the **HER2(+)** class frequently.
#
# Differently from the Vision Transformer it struggles to capture the overall distribution of the labels and the distinguishing features of the other classes.

# %% [markdown]
# # **Inference**

# %%
# Remove training images from memory to prevent RAM saturation
import gc

del train_images
gc.collect()
torch.cuda.empty_cache()

# %%
# @title Load .npz with Tiles


# LOAD TEST DATA
test = np.load(test_tiles_compressed_path)

test_images  = test["images"]
test_names   = test["names"]
test_weights = test["weights"]

print(test_images.shape, test_weights.shape)

# Chosing to use mask-weighted soft voting or not
WEIGHTED = False
# Out:
# (2707, 224, 224, 3) (2707,)

# %%
import torch
from torchvision import transforms

test_preprocessing = None

class TestDataset(torch.utils.data.Dataset):
    def __init__(self, images, transform=None):
        self.images = images
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]


        img_tensor = torch.from_numpy(img).permute(2, 0, 1).float()

        if self.transform:
            img_tensor = self.transform(img_tensor)
        return img_tensor, idx

# %%
test_ds = TestDataset(test_images, transform=test_preprocessing)
test_loader = make_loader(test_ds, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

# %%
ft_model.eval()
test_predictions = []

with torch.no_grad():
    for imgs, idxs in test_loader:

        imgs = imgs.to(torch.float32).to(device)
        logits = ft_model(imgs)
        preds = logits.argmax(dim=1).cpu().numpy()
        test_predictions.append(preds)

test_predictions = np.concatenate(test_predictions)

# %%
# @title Mask-weighted soft voting

from collections import defaultdict

def tile_voting_weighted(names, predictions, weights):
    groups = defaultdict(list)

    for name, pred, w in zip(names, predictions, weights):
        base = name.split("_t")[0]   # es: "img_0091"
        groups[base].append((pred, w))

    final_preds = {}

    for img_name, items in groups.items():
        class_scores = defaultdict(float)

        # Somma pesi per ogni classe
        for pred, w in items:
            class_scores[pred] += w

        # prendi la classe con peso totale maggiore
        winner = max(class_scores, key=class_scores.get)
        final_preds[img_name] = int(winner)

    return final_preds

# %%
# @title Hard voting

from collections import defaultdict
from scipy.stats import mode
import numpy as np

def tile_voting_mode(names, predictions):
    groups = defaultdict(list)

    # raggruppa per immagine
    for name, pred in zip(names, predictions):
        base = name.split("_t")[0]
        groups[base].append(pred)

    final_preds = {}

    for img_name, preds in groups.items():
        preds = np.array(preds)
        winner = mode(preds, keepdims=True)[0][0]
        final_preds[img_name] = int(winner)

    return final_preds

# %%
# Performing voting

if WEIGHTED:
  print("Using weighted voting")
  final_predictions = tile_voting_weighted(
      test_names,
      test_predictions,
      test_weights
  )
else:
  print("Using mode voting")
  final_predictions = tile_voting_mode(
      test_names,
      test_predictions
  )

for img, pred in final_predictions.items():
    print(img, "→ predicted class:", pred)
# Out:
# Using mode voting
# img_0000 → predicted class: 0
# img_0001 → predicted class: 2
# img_0002 → predicted class: 1
# img_0003 → predicted class: 2
# img_0004 → predicted class: 1
# img_0005 → predicted class: 2
# img_0006 → predicted class: 2
# img_0007 → predicted class: 0
# img_0008 → predicted class: 2
# img_0009 → predicted class: 0
# img_0010 → predicted class: 1
# img_0011 → predicted class: 2
# img_0012 → predicted class: 2
# img_0013 → predicted class: 1
# img_0014 → predicted class: 2
# img_0015 → predicted class: 2
# img_0016 → predicted class: 1
# img_0017 → predicted class: 2
# img_0018 → predicted class: 0
# img_0019 → predicted class: 2
# img_0020 → predicted class: 2
# img_0021 → predicted class: 2
# img_0022 → predicted class: 2
# img_0023 → predicted class: 2
# img_0024 → predicted class: 2
# img_0025 → predicted class: 0
# img_0026 → predicted class: 2
# img_0027 → predicted class: 0
# img_0028 → predicted class: 0
# img_0029 → predicted class: 2
# img_0030 → predicted class: 2
# img_0031 → predicted class: 2
# img_0032 → predicted class: 0
# img_0033 → predicted class: 3
# img_0034 → predicted class: 2
# img_0035 → predicted class: 2
# img_0036 → predicted class: 1
# img_0037 → predicted class: 2
# img_0038 → predicted class: 0
# img_0039 → predicted class: 0
# img_0040 → predicted class: 0
# img_0041 → predicted class: 0
# img_0042 → predicted class: 2
# img_0043 → predicted class: 0
# img_0044 → predicted class: 0
# img_0045 → predicted class: 0
# img_0046 → predicted class: 2
# img_0047 → predicted class: 3
# img_0048 → predicted class: 1
# img_0049 → predicted class: 2
# img_0050 → predicted class: 0
# img_0051 → predicted class: 2
# img_0052 → predicted class: 0
# img_0053 → predicted class: 1
# img_0054 → predicted class: 0
# img_0055 → predicted class: 2
# img_0056 → predicted class: 0
# img_0057 → predicted class: 1
# img_0058 → predicted class: 2
# img_0059 → predicted class: 2
# img_0060 → predicted class: 0
# img_0061 → predicted class: 1
# img_0062 → predicted class: 0
# img_0063 → predicted class: 2
# img_0064 → predicted class: 0
# img_0065 → predicted class: 3
# img_0066 → predicted class: 1
# img_0067 → predicted class: 1
# img_0068 → predicted class: 2
# img_0069 → predicted class: 0
# img_0070 → predicted class: 2
# img_0071 → predicted class: 2
# img_0072 → predicted class: 2
# img_0073 → predicted class: 2
# img_0074 → predicted class: 0
# img_0075 → predicted class: 2
# img_0076 → predicted class: 0
# img_0077 → predicted class: 2
# img_0078 → predicted class: 0
# img_0079 → predicted class: 2
# img_0080 → predicted class: 2
# img_0081 → predicted class: 0
# img_0082 → predicted class: 1
# img_0083 → predicted class: 2
# img_0084 → predicted class: 1
# img_0085 → predicted class: 1
# img_0086 → predicted class: 0
# img_0087 → predicted class: 1
# img_0088 → predicted class: 1
# img_0089 → predicted class: 2
# img_0090 → predicted class: 0
# img_0091 → predicted class: 2
# img_0092 → predicted class: 2
# img_0093 → predicted class: 0
# img_0094 → predicted class: 0
# img_0095 → predicted class: 0
# img_0096 → predicted class: 1
# img_0097 → predicted class: 1
# img_0098 → predicted class: 0
# img_0099 → predicted class: 2
# img_0100 → predicted class: 0
# img_0101 → predicted class: 1
# img_0102 → predicted class: 2
# img_0103 → predicted class: 2
# img_0104 → predicted class: 2
# img_0105 → predicted class: 2
# img_0106 → predicted class: 1
# img_0107 → predicted class: 1
# img_0108 → predicted class: 2
# img_0109 → predicted class: 0
# img_0110 → predicted class: 1
# img_0111 → predicted class: 2
# img_0112 → predicted class: 2
# img_0113 → predicted class: 2
# img_0114 → predicted class: 2
# img_0115 → predicted class: 0
# img_0116 → predicted class: 2
# img_0117 → predicted class: 2
# img_0118 → predicted class: 2
# img_0119 → predicted class: 2
# img_0120 → predicted class: 1
# img_0121 → predicted class: 2
# img_0122 → predicted class: 2
# img_0123 → predicted class: 2
# img_0124 → predicted class: 1
# img_0125 → predicted class: 1
# img_0126 → predicted class: 1
# img_0127 → predicted class: 2
# img_0128 → predicted class: 0
# img_0129 → predicted class: 0
# img_0130 → predicted class: 2
# img_0131 → predicted class: 1
# img_0132 → predicted class: 2
# img_0133 → predicted class: 2
# img_0134 → predicted class: 0
# img_0135 → predicted class: 0
# img_0136 → predicted class: 0
# img_0137 → predicted class: 1
# img_0138 → predicted class: 2
# img_0139 → predicted class: 0
# img_0140 → predicted class: 2
# img_0141 → predicted class: 1
# img_0142 → predicted class: 2
# img_0143 → predicted class: 2
# img_0144 → predicted class: 0
# img_0145 → predicted class: 0
# img_0146 → predicted class: 0
# img_0147 → predicted class: 0
# img_0148 → predicted class: 1
# img_0149 → predicted class: 2
# img_0150 → predicted class: 0
# img_0151 → predicted class: 0
# img_0152 → predicted class: 0
# img_0153 → predicted class: 0
# img_0154 → predicted class: 2
# img_0155 → predicted class: 1
# img_0156 → predicted class: 3
# img_0157 → predicted class: 2
# img_0158 → predicted class: 0
# img_0159 → predicted class: 0
# img_0160 → predicted class: 0
# img_0161 → predicted class: 0
# img_0162 → predicted class: 2
# img_0163 → predicted class: 2
# img_0164 → predicted class: 1
# img_0165 → predicted class: 2
# img_0166 → predicted class: 2
# img_0167 → predicted class: 2
# img_0168 → predicted class: 2
# img_0169 → predicted class: 2
# img_0170 → predicted class: 2
# img_0171 → predicted class: 2
# img_0172 → predicted class: 1
# img_0173 → predicted class: 0
# img_0174 → predicted class: 0
# img_0175 → predicted class: 2
# img_0176 → predicted class: 2
# img_0177 → predicted class: 2
# img_0178 → predicted class: 1
# img_0179 → predicted class: 2
# img_0180 → predicted class: 2
# img_0181 → predicted class: 2
# img_0182 → predicted class: 1
# img_0183 → predicted class: 0
# img_0184 → predicted class: 2
# img_0185 → predicted class: 2
# img_0186 → predicted class: 1
# img_0187 → predicted class: 2
# img_0188 → predicted class: 2
# img_0189 → predicted class: 0
# img_0190 → predicted class: 1
# img_0191 → predicted class: 0
# img_0192 → predicted class: 0
# img_0193 → predicted class: 2
# img_0194 → predicted class: 3
# img_0195 → predicted class: 0
# img_0196 → predicted class: 2
# img_0197 → predicted class: 0
# img_0198 → predicted class: 2
# img_0199 → predicted class: 0
# img_0200 → predicted class: 2
# img_0201 → predicted class: 2
# img_0202 → predicted class: 2
# img_0203 → predicted class: 2
# img_0204 → predicted class: 2
# img_0205 → predicted class: 2
# img_0206 → predicted class: 2
# img_0207 → predicted class: 2
# img_0208 → predicted class: 2
# img_0209 → predicted class: 2
# img_0210 → predicted class: 2
# img_0211 → predicted class: 2
# img_0212 → predicted class: 2
# img_0213 → predicted class: 2
# img_0214 → predicted class: 2
# img_0215 → predicted class: 0
# img_0216 → predicted class: 2
# img_0217 → predicted class: 2
# img_0218 → predicted class: 2
# img_0219 → predicted class: 1
# img_0220 → predicted class: 2
# img_0221 → predicted class: 2
# img_0222 → predicted class: 0
# img_0223 → predicted class: 2
# img_0224 → predicted class: 0
# img_0225 → predicted class: 1
# img_0226 → predicted class: 2
# img_0227 → predicted class: 2
# img_0228 → predicted class: 2
# img_0229 → predicted class: 2
# img_0230 → predicted class: 2
# img_0231 → predicted class: 1
# img_0232 → predicted class: 2
# img_0233 → predicted class: 2
# img_0234 → predicted class: 1
# img_0235 → predicted class: 2
# img_0236 → predicted class: 1
# img_0237 → predicted class: 2
# img_0238 → predicted class: 2
# img_0239 → predicted class: 2
# img_0240 → predicted class: 0
# img_0241 → predicted class: 0
# img_0242 → predicted class: 0
# img_0243 → predicted class: 1
# img_0244 → predicted class: 0
# img_0245 → predicted class: 2
# img_0246 → predicted class: 2
# img_0247 → predicted class: 0
# img_0248 → predicted class: 2
# img_0249 → predicted class: 1
# img_0250 → predicted class: 0
# img_0251 → predicted class: 2
# img_0252 → predicted class: 2
# img_0253 → predicted class: 2
# img_0254 → predicted class: 0
# img_0255 → predicted class: 0
# img_0256 → predicted class: 1
# img_0257 → predicted class: 0
# img_0258 → predicted class: 1
# img_0259 → predicted class: 0
# img_0260 → predicted class: 2
# img_0261 → predicted class: 0
# img_0262 → predicted class: 1
# img_0263 → predicted class: 2
# img_0264 → predicted class: 0
# img_0265 → predicted class: 2
# img_0266 → predicted class: 0
# img_0267 → predicted class: 2
# img_0268 → predicted class: 2
# img_0269 → predicted class: 0
# img_0270 → predicted class: 2
# img_0271 → predicted class: 1
# img_0272 → predicted class: 2
# img_0273 → predicted class: 1
# img_0274 → predicted class: 1
# img_0275 → predicted class: 2
# img_0276 → predicted class: 2
# img_0277 → predicted class: 2
# img_0278 → predicted class: 2
# img_0279 → predicted class: 2
# img_0280 → predicted class: 0
# img_0281 → predicted class: 2
# img_0282 → predicted class: 2
# img_0283 → predicted class: 2
# img_0284 → predicted class: 0
# img_0285 → predicted class: 0
# img_0286 → predicted class: 0
# img_0287 → predicted class: 2
# img_0288 → predicted class: 1
# img_0289 → predicted class: 1
# img_0290 → predicted class: 3
# img_0291 → predicted class: 2
# img_0292 → predicted class: 2
# img_0293 → predicted class: 2
# img_0294 → predicted class: 1
# img_0295 → predicted class: 2
# img_0296 → predicted class: 1
# img_0297 → predicted class: 2
# img_0298 → predicted class: 2
# img_0299 → predicted class: 2
# img_0300 → predicted class: 2
# img_0301 → predicted class: 2
# img_0302 → predicted class: 2
# img_0303 → predicted class: 1
# img_0304 → predicted class: 2
# img_0305 → predicted class: 2
# img_0306 → predicted class: 2
# img_0307 → predicted class: 2
# img_0308 → predicted class: 2
# img_0309 → predicted class: 2
# img_0310 → predicted class: 0
# img_0311 → predicted class: 0
# img_0312 → predicted class: 2
# img_0313 → predicted class: 3
# img_0314 → predicted class: 1
# img_0315 → predicted class: 2
# img_0316 → predicted class: 2
# img_0317 → predicted class: 2
# img_0318 → predicted class: 2
# img_0319 → predicted class: 0
# img_0320 → predicted class: 1
# img_0321 → predicted class: 1
# img_0322 → predicted class: 2
# img_0323 → predicted class: 2
# img_0324 → predicted class: 0
# img_0325 → predicted class: 1
# img_0326 → predicted class: 2
# img_0327 → predicted class: 2
# img_0328 → predicted class: 1
# img_0329 → predicted class: 2
# img_0330 → predicted class: 2
# img_0331 → predicted class: 1
# img_0332 → predicted class: 2
# img_0333 → predicted class: 2
# img_0334 → predicted class: 0
# img_0335 → predicted class: 0
# img_0336 → predicted class: 0
# img_0337 → predicted class: 2
# img_0338 → predicted class: 2
# img_0339 → predicted class: 1
# img_0340 → predicted class: 2
# img_0341 → predicted class: 0
# img_0342 → predicted class: 1
# img_0343 → predicted class: 2
# img_0344 → predicted class: 2
# img_0345 → predicted class: 2
# img_0346 → predicted class: 2
# img_0347 → predicted class: 2
# img_0348 → predicted class: 2
# img_0349 → predicted class: 1
# img_0350 → predicted class: 1
# img_0351 → predicted class: 0
# img_0352 → predicted class: 0
# img_0353 → predicted class: 0
# img_0354 → predicted class: 2
# img_0355 → predicted class: 2
# img_0356 → predicted class: 2
# img_0357 → predicted class: 1
# img_0358 → predicted class: 0
# img_0359 → predicted class: 2
# img_0360 → predicted class: 2
# img_0361 → predicted class: 0
# img_0362 → predicted class: 1
# img_0363 → predicted class: 0
# img_0364 → predicted class: 2
# img_0365 → predicted class: 2
# img_0366 → predicted class: 0
# img_0367 → predicted class: 2
# img_0368 → predicted class: 0
# img_0369 → predicted class: 2
# img_0370 → predicted class: 1
# img_0371 → predicted class: 2
# img_0372 → predicted class: 2
# img_0373 → predicted class: 2
# img_0374 → predicted class: 1
# img_0375 → predicted class: 0
# img_0376 → predicted class: 2
# img_0377 → predicted class: 0
# img_0378 → predicted class: 0
# img_0379 → predicted class: 2
# img_0380 → predicted class: 1
# img_0381 → predicted class: 2
# img_0382 → predicted class: 2
# img_0383 → predicted class: 0
# img_0384 → predicted class: 2
# img_0385 → predicted class: 2
# img_0386 → predicted class: 2
# img_0387 → predicted class: 2
# img_0388 → predicted class: 1
# img_0389 → predicted class: 0
# img_0390 → predicted class: 0
# img_0391 → predicted class: 2
# img_0392 → predicted class: 0
# img_0393 → predicted class: 2
# img_0394 → predicted class: 1
# img_0395 → predicted class: 1
# img_0396 → predicted class: 2
# img_0397 → predicted class: 2
# img_0398 → predicted class: 1
# img_0399 → predicted class: 0
# img_0400 → predicted class: 2
# img_0401 → predicted class: 1
# img_0402 → predicted class: 2
# img_0403 → predicted class: 0
# img_0404 → predicted class: 2
# img_0405 → predicted class: 1
# img_0406 → predicted class: 1
# img_0407 → predicted class: 3
# img_0408 → predicted class: 2
# img_0409 → predicted class: 0
# img_0410 → predicted class: 0
# img_0411 → predicted class: 1
# img_0412 → predicted class: 2
# img_0413 → predicted class: 2
# img_0414 → predicted class: 1
# img_0415 → predicted class: 2
# img_0416 → predicted class: 2
# img_0417 → predicted class: 2
# img_0418 → predicted class: 2
# img_0419 → predicted class: 3
# img_0420 → predicted class: 2
# img_0421 → predicted class: 0
# img_0422 → predicted class: 0
# img_0423 → predicted class: 2
# img_0424 → predicted class: 2
# img_0425 → predicted class: 1
# img_0426 → predicted class: 1
# img_0427 → predicted class: 0
# img_0428 → predicted class: 2
# img_0429 → predicted class: 0
# img_0430 → predicted class: 1
# img_0431 → predicted class: 0
# img_0432 → predicted class: 0
# img_0433 → predicted class: 2
# img_0434 → predicted class: 2
# img_0435 → predicted class: 1
# img_0436 → predicted class: 2
# img_0437 → predicted class: 2
# img_0438 → predicted class: 2
# img_0439 → predicted class: 2
# img_0440 → predicted class: 2
# img_0441 → predicted class: 2
# img_0442 → predicted class: 2
# img_0443 → predicted class: 2
# img_0444 → predicted class: 2
# img_0445 → predicted class: 2
# img_0446 → predicted class: 1
# img_0447 → predicted class: 2
# img_0448 → predicted class: 2
# img_0449 → predicted class: 1
# img_0450 → predicted class: 2
# img_0451 → predicted class: 0
# img_0452 → predicted class: 2
# img_0453 → predicted class: 2
# img_0454 → predicted class: 1
# img_0455 → predicted class: 2
# img_0456 → predicted class: 2
# img_0457 → predicted class: 0
# img_0458 → predicted class: 0
# img_0459 → predicted class: 2
# img_0460 → predicted class: 1
# img_0461 → predicted class: 1
# img_0462 → predicted class: 2
# img_0463 → predicted class: 2
# img_0464 → predicted class: 0
# img_0465 → predicted class: 0
# img_0466 → predicted class: 2
# img_0467 → predicted class: 2
# img_0468 → predicted class: 2
# img_0469 → predicted class: 2
# img_0470 → predicted class: 1
# img_0471 → predicted class: 1
# img_0472 → predicted class: 3
# img_0473 → predicted class: 2
# img_0474 → predicted class: 2
# img_0475 → predicted class: 2
# img_0476 → predicted class: 0

# %%
# Labels dictionary
labels = {
    0: 'Luminal A',
    1: 'Luminal B',
    2: 'HER2(+)',
    3: 'Triple negative',
}

# Convert dict → sorted list
sorted_items = sorted(final_predictions.items(), key=lambda x: x[0])

sample_index = [f"{name}.png" for name, pred in sorted_items]
pred_classes = [pred for name, pred in sorted_items]
pred_labels  = [labels[int(c)] for c in pred_classes]

submission_df = pd.DataFrame({
    "sample_index": sample_index,
    "label": pred_labels
})

display(submission_df.head())
print(submission_df["label"].value_counts())
# Out:
#    sample_index      label
# 0  img_0000.png  Luminal A
# 1  img_0001.png    HER2(+)
# 2  img_0002.png  Luminal B
# 3  img_0003.png    HER2(+)
# 4  img_0004.png  Luminal B
# label
# HER2(+)            253
# Luminal A          123
# Luminal B           91
# Triple negative     10
# Name: count, dtype: int64

# %%
# Save the submission DataFrame to a CSV file with the specified format

submission_df.to_csv(submission_dir+f'submission_'+experiment_name+'.csv', index=False)
print("Submission file updated with the correct format and saved successfully!")
# Out:
# Submission file updated with the correct format and saved successfully!
